# %%
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#             BRAND PRODUCT_CATEGORY IS_CHILD_CATEGORY_TO  \
# 0  gillette venus     hair removal    health & wellness
# 1  gillette venus     hair removal    health & wellness
# 2  gillette venus     hair removal    health & wellness
# 3      burts bees     hair removal    health & wellness
# 4      burts bees     hair removal    health & wellness
#
#                                                OFFER        RETAILER
# 0   gillette venus ® for pubic hair & skin spend $20  gillette venus
# 1             gillette venus ® for pubic hair & skin  gillette venus
# 2  gillette venus ® for pubic hair & skin, spend $20  gillette venus
# 3  burt's bees sensitive lotions and creams, sele...         walmart
# 4  burt's bee's® facial wipes, select varieties, ...         walmart

# %%
# Load pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# %%
def get_similarity_score(query, offer):
    # Tokenize and encode the query and offer
    tokens = tokenizer([query, offer], padding=True, truncation=True, return_tensors='pt')
    outputs = model(**tokens)
    embeddings = outputs.last_hidden_state
    
    # Get the embeddings for each sentence
    query_embedding = embeddings[0].mean(dim=1).squeeze().detach().numpy()
    offer_embedding = embeddings[1].mean(dim=1).squeeze().detach().numpy()
    
    # Reshape the embeddings to 2D arrays
    query_embedding = query_embedding.reshape(1, -1)
    offer_embedding = offer_embedding.reshape(1, -1)
    
    # Calculate cosine similarity
    similarity = cosine_similarity(query_embedding, offer_embedding)[0][0]
    return similarity

# %%
def search_offers(query, df):
    # Filter the DataFrame based on multiple columns and query
    mask = df.apply(lambda row: any(query.lower() in str(row[col]).lower() for col in ['BRAND', 'PRODUCT_CATEGORY', 'IS_CHILD_CATEGORY_TO', 'RETAILER']), axis=1)
    filtered_df = df[mask]
    
    # Calculate similarity score for each offer and add it to the DataFrame
    filtered_df['SIMILARITY_SCORE'] = filtered_df['OFFER'].apply(lambda x: get_similarity_score(query, x))
    
    # Sort by similarity score in descending order
    filtered_df = filtered_df.sort_values(by='SIMILARITY_SCORE', ascending=False)
    
    # Return the filtered DataFrame
    return filtered_df

# %%
query = input("Enter category, brand, or retailer: ")

results = search_offers(query, df)
print(len(results))
results.head(15)
# Out:
# 37
#           BRAND PRODUCT_CATEGORY IS_CHILD_CATEGORY_TO  \
# 259    snickers            candy               snacks
# 258    snickers            candy               snacks
# 269  lifesavers            candy               snacks
# 257        m&ms            candy               snacks
# 736       extra              gum                candy
# 261        twix            candy               snacks
# 256        m&ms            candy               snacks
# 270   starburst            candy               snacks
# 274   starburst              gum                candy
# 738       orbit              gum                candy
# 739       orbit              gum                candy
# 275   starburst              gum                candy
# 271   starburst            candy               snacks
# 260        twix            candy               snacks
# 737       extra              gum                candy
#
#                                                OFFER    RETAILER  \
# 259  snickers® chocolate candy bar, select varieties    snickers
# 258                   snickers®, select sizes, buy 1    snickers
# 269                     lifesavers®, any size, buy 1  lifesavers
# 257       m&m's® chocolate candies, select varieties        m&ms
# 736                         extra®, select varieties       extra
# 261                          twix®, select varieties        twix
# 256                      m&m's®, select sizes, buy 1        m&ms
# 270                  starburst®, select sizes, buy 1   starburst
# 274                  starburst®, select sizes, buy 1   starburst
# 738                      orbit®, select sizes, buy 1       orbit
# 739                         orbit®, select varieties       orbit
# 275                     starburst®, select varieties   starburst
# 271                     starburst®, select varieties   starburst
# 260                              twix®, select sizes        twix
# 737                             extra®, select sizes       extra
#
#      SIMILARITY_SCORE
# 259          0.968787
# 258          0.960890
# 269          0.958270
# 257          0.951028
# 736          0.949993
# 261          0.949412
# 256          0.949025
# 270          0.947556
# 274          0.947556
# 738          0.947280
# 739          0.947224
# 275          0.946414
# 271          0.946414
# 260          0.944655
# 737          0.942668
